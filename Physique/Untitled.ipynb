# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

def f(x,y):
    return x**2

# fig = plt.figure()
# ax = fig.gca(projection='3d')
# x, y, z = np.meshgrid(np.arange(0,10),
#                       np.arange(0,10),
#                       np.arange(0,10))
# u = x*y
# v = (1/2)*(x**2) + 3*x
# w = u+v
x = np.arange(0,10)
y = np.arange(0,10)
u = x*y
v = (1/2)*(x**2) + 3*x
plt.plot(u,v)
# ax.quiver(x,y,z,u,v,w,length=0.5, normalize=True)
# plt.ylabel('axis y')
# plt.xlabel('axis x')
# # plt.axis([0,6,0,20])
plt.show()
